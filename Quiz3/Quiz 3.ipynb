# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 3 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here
print("Matthew Dang")
# Out:
# Matthew Dang

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:

print("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy" and "pandas"

# %%
# Write your answer here
import numpy as np
import pandas as pd

# %% [markdown]
# <font size = "5">
#
# (a) Replace the values of a column
#
# <font size = "3">
#
# - Import the "data_raw/constructors.csv" file
# - Replace the values "British", "Japanese", and "Irish" with <br>
# "UK", "Japan", "Ireland" in the column "nationality"
#
#
# HINT: See the example in Lecture 12

# %%
# Write your own code
constructors = pd.read_csv("data_raw/constructors.csv")
constructors['nationality'] = constructors['nationality'].replace({
    'British' : 'UK',
    'Japanese' : 'Japan',
    'Irish' : 'Ireland'
})

# %% [markdown]
# <font size = "5">
#
# (b) Aggregate and query
#
# <font size = "3">
#
# - Import the "data_raw/sprint_results.csv" file
# - Subset the observations for 'constructorId == 3' using ```.query()```
# - Obtain the maximum of "laps" by "driverId" <br>
#  using ``` .groupby().agg() ```
# - Subset the drivers with a maximum of laps $\ge 10$
# - Store the results of all these operations in a dataframe <br>
# ```sprint_results_agg ```

# %%
# Write your own code
sprint_results = pd.read_csv("data_raw/sprint_results.csv")
constructorId3 = sprint_results.query('constructorId == 3')
# print(constructorId3.head())
grouped_results = constructorId3.groupby('driverId').agg({
    'laps' : 'max'
})
# print(grouped_results.head())
sprint_results_agg = grouped_results[grouped_results['laps'] >= 10]
print(sprint_results_agg.head(5))
# Out:
#           laps
# driverId
# 847         24
# 848         23
# 849         24

# %% [markdown]
# <font size = "5">
#
# (c) Recode a numeric colum
#
# <font size = "3">
#
# - Import the "data_raw/races.csv" file
# - Recode the "year" column into a new column "year_brackets" <br>
# with the following categories
#
# $\qquad$ ``` ["1950-1965","1966-1980","1980-onwards"] ```
#
# $\qquad$ HINT: Use the "pd.cut()" command.

# %%
# Write your own code
races = pd.read_csv("data_raw/races.csv")
races['year_brackets'] = pd.cut(
    races['year'],
    bins=[1950, 1965, 1980, 2025],
    labels=["1950-1965", "1966-1980", "1981-onwards"],
    right = True
)
print(races[['year', 'year_brackets']])
# Out:
#       year year_brackets
# 0     2009  1980-onwards
# 1     2009  1980-onwards
# 2     2009  1980-onwards
# 3     2009  1980-onwards
# 4     2009  1980-onwards
# ...    ...           ...
# 1097  2023  1980-onwards
# 1098  2023  1980-onwards
# 1099  2023  1980-onwards
# 1100  2023  1980-onwards
# 1101  2023  1980-onwards
#
# [1102 rows x 2 columns]

# %% [markdown]
# <font size = "5">
#
# (d) Aggregate and sort
#
# <font size = "3">
#
# - Import the "data_raw/sprint_results.csv" file
# - Obtain the maximum of "laps" by "driverId" <br>
# using ``` .groupby().agg() ```
# - Sort the teams in descending order using of <br>
# the maximum of laps using ``` .sort_values() ```

# %%
# Write your own code
sprint_results = pd.read_csv("data_raw/sprint_results.csv")
max_laps = sprint_results.groupby('driverId').agg({
    'laps' : 'max'
})
max_laps_sorted = max_laps.sort_values(by='laps', ascending=False)
print(max_laps_sorted.head(5))
# Out:
#           laps
# driverId
# 1           24
# 4           24
# 854         24
# 853         24
# 852         24

# %% [markdown]
# <font size = "5">
#
# (e) Rename column
#
# <font size = "3">
#
# - Import the "data_raw/sprint_results.csv" file
# - Rename the column "time" to "time_unformatted"
#
# HINT: Create a dictionary and use ```.rename(columns = ...)``` <br>
# See Lecture 15

# %%
# Write your own code
sprint_results = pd.read_csv("data_raw/sprint_results.csv")
column_dictionary = {
    'time' : 'time_unformatted'
}
sprint_results_named = sprint_results.rename(columns=column_dictionary)
print(sprint_results_named[['time_unformatted']].head())
# Out:
#   time_unformatted
# 0        25:38.426
# 1           +1.430
# 2           +7.502
# 3          +11.278
# 4          +24.111

# %% [markdown]
# <font size = "5">
#
# (f) Merge dataset
#
# <font size = "3">
#
# - Import the "data_raw/sprint_results.csv" and <br>
# "data_raw/constructors.csv" files
# - Create a new dataset with  ```pd.merge()``` using <br>
# "sprint_results" as the primary dataset, and <br>
# "constructors" as the secondary dataset, merging on <br>
# the column "constructorId"
# - To get full points **ONLY** merge the "nationality" column <br>
# from the secondary dataset (not all the columns)
#
# HINT: Use ```[[...]]``` to extract a subset of columns <br>
# from the secondary dataset before merging, including the <br>
# "constructorId" column

# %%
# Write your own code
sprint_results = pd.read_csv("data_raw/sprint_results.csv")
constructors = pd.read_csv("data_raw/constructors.csv")
results_merged = pd.merge(sprint_results[['constructorId']], 
        constructors[['constructorId', 'nationality']], 
        on='constructorId')
print(results_merged.head())
# Out:
#    constructorId nationality
# 0              9    Austrian
# 1            131      German
# 2            131      German
# 3              6     Italian
# 4              1     British
